# %%
from generate_dataset import generate_dataset

df = generate_dataset(num_records=1000, seed=42)
df.head()
# Out:
#    member_id  nb_card_transactions_last_90d  average_balance_last_90d  \
# 0          1                              1                  6.000000
# 1          2                              0                  0.000000
# 2          3                             42              14413.115386
# 3          4                             26                  5.000000
# 4          5                              0                  5.000000
#
#   has_churned
# 0           Y
# 1           Y
# 2           Y
# 3           Y
# 4           N

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.jointplot(x='nb_card_transactions_last_90d', y='average_balance_last_90d', data=df, kind='scatter', color='skyblue')
plt.suptitle('Card Transactions vs Average Balance', y=1.02)
plt.show()
